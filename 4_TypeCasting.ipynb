# %% [markdown]
# **TYPE CASTING**

# %%
- change one data type to another data type
- Int ----> float
- Int ----> string
- Int ----> boolean
- Int ----> complex

- float ----> int
- float ----> string
- float ----> boolean
- float ----> complex

# %% [markdown]
# **Integer to other data types**

# %%
number1=100
number1
# Out:
# 100

# %%
type(number1)
# Out:
# int

# %%
# case 1: int ---> float
float(number1)
# Out:
# 100.0

# %%
float_number=float(number1)

# %%
float_number
# Out:
# 100.0

# %%
type(float_number)
# Out:
# float

# %%
# case 2:100 =====string===='100'
string_number=str(number1)
string_number
# Out:
# '100'

# %%
type(string_number)
# Out:
# str

# %%
# case 3: 100 =====boolean==== True or False 
boolean_number=bool(number1)
boolean_number
# Out:
# True

# %%
type(boolean_number)
# Out:
# bool

# %%
bool(100) #How to will come False
# Out:
# True

# %%
bool(0)
# Out:
# False

# %% [markdown]
# **Note**
# - other than zero, everything is True
# - bool(0) only False

# %%
# case 4:100=====? complex(100)
complex_number=complex(number1)
complex_number
# Out:
# (100+0j)

# %%
# Example
number2=500
Float_number=float(number2)
Float_number
#string_number=str(number2)
#string_number
#boolean_number=bool(number2)
#boolean_number
#complex_number=complex(number2)
#complex_number
# Out:
# 500.0

# %% [markdown]
# ***convert float to all other types***

# %%
number3=300.5
int_number=int(number3)
int_number
# Out:
# 300

# %%
string_number=str(number3)
string_number
# Out:
# '300.5'

# %%
boolean_number=bool(number3)
boolean_number
# Out:
# True

# %%
complex_number=complex(number3)
complex_number
# Out:
# (300.5+0j)

# %% [markdown]
# **String to other data types**

# %%
string=''
bool_number=bool(string)
bool_number
# Out:
# False

# %% [markdown]
# **Note**:
#   Empty string boolean conversion given as False

# %%
string='apple'
bool_number=bool(string)
bool_number
# Out:
# True

# %%
complex_number=complex(string)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 complex_number=complex(string)
#
# ValueError: complex() arg is a malformed string

# %%
float_number=float(string)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 float_number=float(string)
#
# ValueError: could not convert string to float: 'apple'

# %%
string='apple'
bool_number=bool(string)         #True
float_number=float(string)       #error
complex_number=complex(string)   #error
int_number=int(string)           #error

# %%
string1='10.5'
bool_number=bool(string1)         #True
float_number=float(string1)       #10.5
complex_number=complex(string1)   #10.5+0j
int_number=int(string1)           #error

# %%
string1='10.5'
bool_number=bool(string1) 
bool_number
# Out:
# True

# %%
string1='10.5'
float_number=float(string1) 
float_number
# Out:
# 10.5

# %%
string=10.5
complex_number=complex(string)
complex_number
# Out:
# (10.5+0j)

# %%
string=10.5
int_number=int(string1)
int_number
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 2
#       1 string=10.5
# ----> 2 int_number=int(string1)
#       3 int_number
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
string1='10.5'
bool_number=bool(string1)         #True
float_number=float(string1)       #10.5
complex_number=complex(string1)   #10.5+0j
int_number=int(string1)           #error

# %%
# Boolean conversation
val1=True
int(val1)
# Out:
# 1

# %%
float(val1)
# Out:
# 1.0

# %%
str(val1)
# Out:
# 'True'

# %%
complex(val1)
# Out:
# (1+0j)

# %%
# complex to other
val2=100+200j
int(val2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 3
#       1 # complex to other
#       2 val2=100+200j
# ----> 3 int(val2)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
float(val2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 float(val2)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
str(val2)
# Out:
# '(100+200j)'

# %%
bool(val2)
# Out:
# True

# %%
val3=100+0j
int(val3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 2
#       1 val3=100+0j
# ----> 2 int(val3)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
float(val3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 float(val3)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
str(val3)
# Out:
# '(100+0j)'

# %%
complex(val3)
# Out:
# (100+0j)

# %%
bool(val3)
# Out:
# True

# %%
if __name__ == '__main__':
    n = int(input())
    for i in range (1,n):
        print(i,end="")
# Out:
#  5
# 1234
